# %%
# Generate All Paper Figures
import subprocess
subprocess.run(['python', 'visualization/plot_per_family.py', '--output', 'paper/figures/fig4_per_family.pdf'])
subprocess.run(['python', 'visualization/plot_ablation.py',   '--output', 'paper/figures/fig5_ablation.pdf'])
print('Figures generated.')
