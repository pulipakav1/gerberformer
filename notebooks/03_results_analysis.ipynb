# %%
# Results Analysis
import json
import matplotlib.pyplot as plt
import numpy as np

with open('paper/results/ALL_PAPER_RESULTS.json') as f:
    results = json.load(f)
print(json.dumps(results, indent=2))

# %%
# Generalization gap visualization
baseline_unseen = results['table3_generalization']['baseline']['unseen_mean']
gerber_unseen   = results['table3_generalization']['gerber']['unseen_mean']
print(f'Baseline unseen: {baseline_unseen:.4f}')
print(f'Gerber unseen:   {gerber_unseen:.4f}')
print(f'Improvement:     +{gerber_unseen - baseline_unseen:.4f}')
